# %% [markdown]
# # Mini Project

# %%
import openpyxl

# %%
import pandas as pd

# %%
workbook =openpyxl.Workbook()
sheet =workbook.active

# %%
data=[
    ['Name','Domain','Age','Location','Salary','Exp'],
    ['Mohit','IT', 25 ,'Hyd', 10000 , 3],
    ['Shoaib','FDS', 21 ,'Hyd', 20000 , 1],
    ['Mohammed','Testing', 35 ,'Hyd', 15000 ,6] ,
    ['Muneer','Data Analist', 45,'Hyd', 35000 , 20] ,
    ['Mehran','scatch',14,'Hyd', 10000 , 1],
    ['Marwan','scatch',12,'Hyd',10000,1]
    
]

for row in data:
    sheet.append(row)

workbook.save('data.xlsx')

# %%
data
# Out:
# [['Name', 'Domain', 'Age', 'Location', 'Salary', 'Exp'],
#  ['Mohit', 'IT', 25, 'Hyd', 10000, 3],
#  ['Shoaib', 'FDS', 21, 'Hyd', 20000, 1],
#  ['Mohammed', 'Testing', 35, 'Hyd', 15000, 6],
#  ['Muneer', 'Data Analist', 45, 'Hyd', 35000, 20],
#  ['Mehran', 'scatch', 14, 'Hyd', 10000, 1],
#  ['Marwan', 'scatch', 12, 'Hyd', 10000, 1]]

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\simra'

# %%
emp=pd.read_excel(r'C:\\Users\\simra\data.xlsx')
emp
# Out:
#        Name        Domain  Age Location  Salary  Exp
# 0     Mohit            IT   25      Hyd   10000    3
# 1    Shoaib           FDS   21      Hyd   20000    1
# 2  Mohammed       Testing   35      Hyd   15000    6
# 3    Muneer  Data Analist   45      Hyd   35000   20
# 4    Mehran        scatch   14      Hyd   10000    1
# 5    Marwan        scatch   12      Hyd   10000    1

# %%
emp.shape  #rows and columns
# Out:
# (6, 6)

# %%
emp.columns   # column is represented
# Out:
# Index(['Name', 'Domain', 'Age', 'Location', 'Salary', 'Exp'], dtype='object')

# %%
len(emp)
# Out:
# 6

# %%
emp['Salary']  #salary colum is represented
# Out:
# 0    10000
# 1    20000
# 2    15000
# 3    35000
# 4    10000
# 5    10000
# Name: Salary, dtype: int64

# %%
emp[['Salary','Exp']] #salary and exp is represented
# Out:
#    Salary  Exp
# 0   10000    3
# 1   20000    1
# 2   15000    6
# 3   35000   20
# 4   10000    1
# 5   10000    1

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Bar Graph

# %%
vis1=sns.displot(emp['Salary'])    # Bar graph representation

# %% [markdown]
# # Greaph line + Bar graph representation

# %%
vis2=sns.distplot(emp['Salary'])  # GRaph with bar ghraph
# Out:
# C:\Users\simra\AppData\Local\Temp\ipykernel_18340\867714885.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   vis2=sns.distplot(emp['Salary'])  # GRaph with bar ghraph

# %%
vis3=plt.hist(emp['Salary'])

# %%
emp
# Out:
#        Name        Domain  Age Location  Salary  Exp
# 0     Mohit            IT   25      Hyd   10000    3
# 1    Shoaib           FDS   21      Hyd   20000    1
# 2  Mohammed       Testing   35      Hyd   15000    6
# 3    Muneer  Data Analist   45      Hyd   35000   20
# 4    Mehran        scatch   14      Hyd   10000    1
# 5    Marwan        scatch   12      Hyd   10000    1

# %% [markdown]
# # Reducing the size of the Bar graph

# %%
plt.rcParams['figure.figsize']=1,5   # size has been reduced

# %%
vis1=sns.displot(emp['Salary'])

# %%
vis5=sns.lmplot(data=emp,x='Exp',y='Salary')  #Creating A graph with ploting and line

# %% [markdown]
# # Ploting Graph

# %%
vis5=sns.lmplot(data=emp,x='Exp',y='Salary',fit_reg=False) #creating a graph with plot without line

# %%
emp
# Out:
#        Name        Domain  Age Location  Salary  Exp
# 0     Mohit            IT   25      Hyd   10000    3
# 1    Shoaib           FDS   21      Hyd   20000    1
# 2  Mohammed       Testing   35      Hyd   15000    6
# 3    Muneer  Data Analist   45      Hyd   35000   20
# 4    Mehran        scatch   14      Hyd   10000    1
# 5    Marwan        scatch   12      Hyd   10000    1

# %% [markdown]
# # Exp and Age graph ploting

# %%
v1=sns.lmplot(data=emp,x='Exp',y='Age')

# %% [markdown]
# # Age and Salary graph ploting

# %%
v1=sns.lmplot(data=emp,x='Age',y='Salary')
